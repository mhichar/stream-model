# %%
import pandas as pd
import boto
from boto import kinesis
from samples.skwrows import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
conn = kinesis.connect_to_region('us-east-1')
conn.describe_stream('Cap-0')
# Out:
# {'StreamDescription': {'EncryptionType': 'NONE',
#   'EnhancedMonitoring': [{'ShardLevelMetrics': []}],
#   'HasMoreShards': False,
#   'RetentionPeriodHours': 24,
#   'Shards': [{'HashKeyRange': {'EndingHashKey': '3402823669209384634633746074317682113',
#      'StartingHashKey': '0'},
#     'SequenceNumberRange': {'StartingSequenceNumber': '49592264047391110286445184464149911991179566280108670978'},
#     'ShardId': 'shardId-000000000000'},
#    {'HashKeyRange': {'EndingHashKey': '6805647338418769269267492148635364228',
#      'StartingHashKey': '3402823669209384634633746074317682114'},
#     'SequenceNumberRange': {'StartingSequenceNumber': '49592264047413411031643715087291447709452214641614651410'},
#     'ShardId': 'shardId-000000000001'},
#    {'HashKeyRange': {'EndingHashKey': '10208471007628153903901238222953046342',
#      'StartingHashKey': '6805647338418769269267492148635364229'},
# ...

# %%
credit_card= 'C:\\Users\\mhichar\\OneDrive - Capgemini\\Data\\creditcard.csv'

# %%
put_words_in_stream_periodically(conn, 'Cap-0', credit_card, 2)
# Out:
# Put row: {"Time":0.0,"V1":-1.3598071337,"V2":-0.0727811733,"V3":2.536346738,"V4":1.3781552243,"V5":-0.3383207699,"V6":0.4623877778,"V7":0.2395985541,"V8":0.0986979013,"V9":0.3637869696,"V10":0.090794172,"V11":-0.5515995333,"V12":-0.6178008558,"V13":-0.9913898472,"V14":-0.3111693537,"V15":1.4681769721,"V16":-0.4704005253,"V17":0.2079712419,"V18":0.0257905802,"V19":0.4039929603,"V20":0.2514120982,"V21":-0.0183067779,"V22":0.2778375756,"V23":-0.1104739102,"V24":0.0669280749,"V25":0.1285393583,"V26":-0.1891148439,"V27":0.1335583767,"V28":-0.0210530535,"Amount":149.62,"Class":0.0} into stream: Cap-0
# ...

# %% [markdown]
# ## Experiment

# %%
conn.get_records()

# %%
df = pd.read_csv(credit_card)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
for i in range(df.shape[0]):
    print(df[i])
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-f9aedabc6dcc> in <module>()
#       1 for i in range(df.shape[0]):
# ...

# %%
strng = list(df.iloc[1,:])

# %%
row0 = df.iloc[0,:]

# %%
row0.to_json()
# Out:
# '{"Time":0.0,"V1":-1.3598071337,"V2":-0.0727811733,"V3":2.536346738,"V4":1.3781552243,"V5":-0.3383207699,"V6":0.4623877778,"V7":0.2395985541,"V8":0.0986979013,"V9":0.3637869696,"V10":0.090794172,"V11":-0.5515995333,"V12":-0.6178008558,"V13":-0.9913898472,"V14":-0.3111693537,"V15":1.4681769721,"V16":-0.4704005253,"V17":0.2079712419,"V18":0.0257905802,"V19":0.4039929603,"V20":0.2514120982,"V21":-0.0183067779,"V22":0.2778375756,"V23":-0.1104739102,"V24":0.0669280749,"V25":0.1285393583,"V26":-0.1891148439,"V27":0.1335583767,"V28":-0.0210530535,"Amount":149.62,"Class":0.0}'

# %%
col = list(df)
data = [list(df[d]) for d in col]

# %%
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
